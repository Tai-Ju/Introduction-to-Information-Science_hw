# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

df
# Out:
#                    A         B         C         D
# 2013-01-01  0.467631  0.785404 -0.311837  0.442165
# 2013-01-02 -1.370189 -0.167433  0.547211 -1.433885
# 2013-01-03 -1.306689  2.556779  1.512791 -0.243519
# 2013-01-04 -1.040370  0.311898 -1.701350  0.684212
# 2013-01-05  0.893343 -0.249570 -1.441420 -1.196015
# 2013-01-06  2.324789  0.113172  0.331476  0.259514

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)


df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.A
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %%
df2.abs
# Out:
# <bound method NDFrame.abs of      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo>

# %%
df2.add
# Out:
# <bound method DataFrame.add of      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo>

# %%
df2.add_prefix
# Out:
# <bound method NDFrame.add_prefix of      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo>

# %%
df2.add_suffix
# Out:
# <bound method NDFrame.add_suffix of      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo>

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.467631  0.785404 -0.311837  0.442165
# 2013-01-02 -1.370189 -0.167433  0.547211 -1.433885
# 2013-01-03 -1.306689  2.556779  1.512791 -0.243519
# 2013-01-04 -1.040370  0.311898 -1.701350  0.684212
# 2013-01-05  0.893343 -0.249570 -1.441420 -1.196015

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -1.040370  0.311898 -1.701350  0.684212
# 2013-01-05  0.893343 -0.249570 -1.441420 -1.196015
# 2013-01-06  2.324789  0.113172  0.331476  0.259514

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.4676313 ,  0.78540439, -0.31183736,  0.44216459],
#        [-1.37018854, -0.16743323,  0.54721137, -1.43388536],
#        [-1.30668945,  2.55677912,  1.51279052, -0.2435189 ],
#        [-1.04037001,  0.31189804, -1.70135033,  0.68421199],
#        [ 0.89334315, -0.24956973, -1.44142035, -1.19601505],
#        [ 2.32478853,  0.11317213,  0.33147617,  0.25951375]])

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.005248  0.558375 -0.177188 -0.247921
# std    1.489190  1.047253  1.231179  0.884081
# min   -1.370189 -0.249570 -1.701350 -1.433885
# 25%   -1.240110 -0.097282 -1.159025 -0.957891
# 50%   -0.286369  0.212535  0.009819  0.007997
# 75%    0.786915  0.667028  0.493278  0.396502
# max    2.324789  2.556779  1.512791  0.684212

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.467631   -1.370189   -1.306689   -1.040370    0.893343    2.324789
# B    0.785404   -0.167433    2.556779    0.311898   -0.249570    0.113172
# C   -0.311837    0.547211    1.512791   -1.701350   -1.441420    0.331476
# D    0.442165   -1.433885   -0.243519    0.684212   -1.196015    0.259514

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.442165 -0.311837  0.785404  0.467631
# 2013-01-02 -1.433885  0.547211 -0.167433 -1.370189
# 2013-01-03 -0.243519  1.512791  2.556779 -1.306689
# 2013-01-04  0.684212 -1.701350  0.311898 -1.040370
# 2013-01-05 -1.196015 -1.441420 -0.249570  0.893343
# 2013-01-06  0.259514  0.331476  0.113172  2.324789

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-05  0.893343 -0.249570 -1.441420 -1.196015
# 2013-01-02 -1.370189 -0.167433  0.547211 -1.433885
# 2013-01-06  2.324789  0.113172  0.331476  0.259514
# 2013-01-04 -1.040370  0.311898 -1.701350  0.684212
# 2013-01-01  0.467631  0.785404 -0.311837  0.442165
# 2013-01-03 -1.306689  2.556779  1.512791 -0.243519

# %%
df["A"]
# Out:
# 2013-01-01    0.467631
# 2013-01-02   -1.370189
# 2013-01-03   -1.306689
# 2013-01-04   -1.040370
# 2013-01-05    0.893343
# 2013-01-06    2.324789
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.467631  0.785404 -0.311837  0.442165
# 2013-01-02 -1.370189 -0.167433  0.547211 -1.433885
# 2013-01-03 -1.306689  2.556779  1.512791 -0.243519

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -1.370189 -0.167433  0.547211 -1.433885
# 2013-01-03 -1.306689  2.556779  1.512791 -0.243519
# 2013-01-04 -1.040370  0.311898 -1.701350  0.684212

# %%
df.loc[dates[0]]
# Out:
# A    0.467631
# B    0.785404
# C   -0.311837
# D    0.442165
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  0.467631  0.785404
# 2013-01-02 -1.370189 -0.167433
# 2013-01-03 -1.306689  2.556779
# 2013-01-04 -1.040370  0.311898
# 2013-01-05  0.893343 -0.249570
# 2013-01-06  2.324789  0.113172

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02 -1.370189 -0.167433
# 2013-01-03 -1.306689  2.556779
# 2013-01-04 -1.040370  0.311898

# %%
df.loc[dates[0], "A"]
# Out:
# np.float64(0.46763129573283246)

# %%
df.at[dates[0], "A"]
# Out:
# np.float64(0.46763129573283246)

# %%
df.iloc[3]
# Out:
# A   -1.040370
# B    0.311898
# C   -1.701350
# D    0.684212
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -1.040370  0.311898
# 2013-01-05  0.893343 -0.249570

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02 -1.370189  0.547211
# 2013-01-03 -1.306689  1.512791
# 2013-01-05  0.893343 -1.441420

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -1.370189 -0.167433  0.547211 -1.433885
# 2013-01-03 -1.306689  2.556779  1.512791 -0.243519

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.785404 -0.311837
# 2013-01-02 -0.167433  0.547211
# 2013-01-03  2.556779  1.512791
# 2013-01-04  0.311898 -1.701350
# 2013-01-05 -0.249570 -1.441420
# 2013-01-06  0.113172  0.331476

# %%
df.iloc[1, 1]
# Out:
# np.float64(-0.16743323485379086)

# %%
df.iat[1, 1]
# Out:
# np.float64(-0.16743323485379086)

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.467631  0.785404 -0.311837  0.442165
# 2013-01-05  0.893343 -0.249570 -1.441420 -1.196015
# 2013-01-06  2.324789  0.113172  0.331476  0.259514

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.467631  0.785404       NaN  0.442165
# 2013-01-02       NaN       NaN  0.547211       NaN
# 2013-01-03       NaN  2.556779  1.512791       NaN
# 2013-01-04       NaN  0.311898       NaN  0.684212
# 2013-01-05  0.893343       NaN       NaN       NaN
# 2013-01-06  2.324789  0.113172  0.331476  0.259514

# %%
df2 = df.copy()

df2["E"] = ["one", "one", "two", "three", "four", "three"]

df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.467631  0.785404 -0.311837  0.442165    one
# 2013-01-02 -1.370189 -0.167433  0.547211 -1.433885    one
# 2013-01-03 -1.306689  2.556779  1.512791 -0.243519    two
# 2013-01-04 -1.040370  0.311898 -1.701350  0.684212  three
# 2013-01-05  0.893343 -0.249570 -1.441420 -1.196015   four
# 2013-01-06  2.324789  0.113172  0.331476  0.259514  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -1.306689  2.556779  1.512791 -0.243519   two
# 2013-01-05  0.893343 -0.249570 -1.441420 -1.196015  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.000000 -0.311837  5.0
# 2013-01-02 -1.370189 -0.167433  0.547211  5.0
# 2013-01-03 -1.306689  2.556779  1.512791  5.0
# 2013-01-04 -1.040370  0.311898 -1.701350  5.0
# 2013-01-05  0.893343 -0.249570 -1.441420  5.0
# 2013-01-06  2.324789  0.113172  0.331476  5.0

# %%
df2 = df.copy()

df2[df2 > 0] = -df2

df2
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.000000 -0.311837 -5.0
# 2013-01-02 -1.370189 -0.167433 -0.547211 -5.0
# 2013-01-03 -1.306689 -2.556779 -1.512791 -5.0
# 2013-01-04 -1.040370 -0.311898 -1.701350 -5.0
# 2013-01-05 -0.893343 -0.249570 -1.441420 -5.0
# 2013-01-06 -2.324789 -0.113172 -0.331476 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

df1.loc[dates[0] : dates[1], "E"] = 1

df1
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.000000 -0.311837  5.0  1.0
# 2013-01-02 -1.370189 -0.167433  0.547211  5.0  1.0
# 2013-01-03 -1.306689  2.556779  1.512791  5.0  NaN
# 2013-01-04 -1.040370  0.311898 -1.701350  5.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.000000 -0.311837  5.0  1.0
# 2013-01-02 -1.370189 -0.167433  0.547211  5.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.000000 -0.311837  5.0  1.0
# 2013-01-02 -1.370189 -0.167433  0.547211  5.0  1.0
# 2013-01-03 -1.306689  2.556779  1.512791  5.0  5.0
# 2013-01-04 -1.040370  0.311898 -1.701350  5.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      E
# 2013-01-01  False  False  False  False  False
# 2013-01-02  False  False  False  False  False
# 2013-01-03  False  False  False  False   True
# 2013-01-04  False  False  False  False   True

# %%
df.mean()
# Out:
# A   -0.083186
# B    0.427474
# C   -0.177188
# D    5.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.172041
# 2013-01-02    1.002397
# 2013-01-03    1.940720
# 2013-01-04    0.642544
# 2013-01-05    1.050588
# 2013-01-06    1.942359
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D
# 2013-01-01       NaN       NaN       NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN
# 2013-01-03 -2.306689  1.556779  0.512791  4.0
# 2013-01-04 -4.040370 -2.688102 -4.701350  2.0
# 2013-01-05 -4.106657 -5.249570 -6.441420  0.0
# 2013-01-06       NaN       NaN       NaN  NaN

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A    -0.465842
# B     2.393857
# C    -0.992255
# D    28.000000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D
# 2013-01-01    0.000000    0.000000  -31.557941  506.0
# 2013-01-02 -138.663080  -16.944243   55.377791  506.0
# 2013-01-03 -132.236972  258.746047  153.094401  506.0
# 2013-01-04 -105.285445   31.564082 -172.176653  506.0
# 2013-01-05   90.406327  -25.256457 -145.871740  506.0
# 2013-01-06  235.268599   11.453019   33.545388  506.0

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

s
# Out:
# 0    3
# 1    4
# 2    1
# 3    2
# 4    4
# 5    0
# 6    5
# 7    1
# 8    2
# 9    1
# dtype: int32

# %%
s.value_counts()
# Out:
# 1    3
# 4    2
# 2    2
# 3    1
# 0    1
# 5    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))

df
# Out:
#           0         1         2         3
# 0 -0.677166  0.320834  0.203069  0.870812
# 1  0.756577  2.105176  0.636753  2.730087
# 2  0.566970  1.085778  0.666776  1.057652
# 3 -0.147977  1.780158 -0.480484  1.348569
# 4  0.453454  0.107453  0.527743  0.021268
# 5 -0.868492 -1.620313 -0.520066  0.847542
# 6  0.538861  1.671802 -0.154759  0.850820
# 7 -0.398416 -1.633177 -1.462683  2.218847
# 8 -0.683473  0.623918  1.011161 -1.005811
# 9  0.639745 -0.244099  0.441595  1.103196

# %%
pieces = [df[:3], df[3:7], df[7:]]

pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.677166  0.320834  0.203069  0.870812
# 1  0.756577  2.105176  0.636753  2.730087
# 2  0.566970  1.085778  0.666776  1.057652
# 3 -0.147977  1.780158 -0.480484  1.348569
# 4  0.453454  0.107453  0.527743  0.021268
# 5 -0.868492 -1.620313 -0.520066  0.847542
# 6  0.538861  1.671802 -0.154759  0.850820
# 7 -0.398416 -1.633177 -1.462683  2.218847
# 8 -0.683473  0.623918  1.011161 -1.005811
# 9  0.639745 -0.244099  0.441595  1.103196

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})

right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)


df
# Out:
#      A      B         C         D
# 0  foo    one -0.142265 -0.578835
# 1  bar    one  0.111758 -0.099320
# 2  foo    two  0.134977 -0.564218
# 3  bar  three -0.273174  2.690674
# 4  foo    two -0.845941  2.399648
# 5  bar    two -0.468576  1.165510
# 6  foo    one  0.300012 -2.051680
# 7  foo  three -0.648897  0.414500

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar -0.629992  3.756864
# foo -1.202114 -0.380585

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    0.111758 -0.099320
#     three -0.273174  2.690674
#     two   -0.468576  1.165510
# foo one    0.157747 -2.630514
#     three -0.648897  0.414500
#     two   -0.710964  1.835430

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]


index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

df2 = df[:4]

df2
# Out:
#                      A         B
# first second
# bar   one    -0.149027  0.174527
#       two    -0.186848 -0.056679
# baz   one    -0.029566  0.892041
#       two     0.266089 -1.418729

# %%
stacked = df2.stack(future_stack=True)

stacked
# Out:
# first  second
# bar    one     A   -0.149027
#                B    0.174527
#        two     A   -0.186848
#                B   -0.056679
# baz    one     A   -0.029566
#                B    0.892041
#        two     A    0.266089
#                B   -1.418729
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.149027  0.174527
#       two    -0.186848 -0.056679
# baz   one    -0.029566  0.892041
#       two     0.266089 -1.418729

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.149027 -0.186848
#       B  0.174527 -0.056679
# baz   A -0.029566  0.266089
#       B  0.892041 -1.418729

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.149027 -0.029566
#        B  0.174527  0.892041
# two    A -0.186848  0.266089
#        B -0.056679 -1.418729

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)


df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -1.540235 -0.808739
# 1     one  B  foo  1.825879 -1.013520
# 2     two  C  foo  0.965009  0.495329
# 3   three  A  bar -0.175114 -1.816994
# 4     one  B  bar -0.159927 -0.681353
# 5     one  C  bar  0.538267  0.011884
# 6     two  A  foo  0.694722  0.034918
# 7   three  B  foo  0.646684  1.065017
# 8     one  C  foo -0.845655 -1.245844
# 9     one  A  bar -1.524788  0.860157
# 10    two  B  bar  0.627907  0.932288
# 11  three  C  bar -0.718817 -2.341777

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A -1.524788 -1.540235
#       B -0.159927  1.825879
#       C  0.538267 -0.845655
# three A -0.175114       NaN
#       B       NaN  0.646684
#       C -0.718817       NaN
# two   A       NaN  0.694722
#       B  0.627907       NaN
#       C       NaN  0.965009

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")

ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

ts.resample("5Min").sum()
# Out:
# 2012-01-01    25369
# Freq: 5min, dtype: int32

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

ts = pd.Series(np.random.randn(len(rng)), rng)

ts
# Out:
# 2012-03-06    0.511626
# 2012-03-07    0.007215
# 2012-03-08   -2.152002
# 2012-03-09   -0.484056
# 2012-03-10   -1.112891
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.511626
# 2012-03-07 00:00:00+00:00    0.007215
# 2012-03-08 00:00:00+00:00   -2.152002
# 2012-03-09 00:00:00+00:00   -0.484056
# 2012-03-10 00:00:00+00:00   -1.112891
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00    0.511626
# 2012-03-06 19:00:00-05:00    0.007215
# 2012-03-07 19:00:00-05:00   -2.152002
# 2012-03-08 19:00:00-05:00   -0.484056
# 2012-03-09 19:00:00-05:00   -1.112891
# Freq: D, dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df["grade"] = df["raw_grade"].astype("category")

df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
In [118]: new_categories = ["very good", "good", "very bad"]

In [119]: df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)


df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

ts.plot();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)


df = df.cumsum()

plt.figure();

df.plot();

plt.legend(loc='best');

# %%
In [134]: df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

In [135]: df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  3  3  3  1  1
# 1           1  3  4  0  0  4
# 2           2  1  2  0  1  2
# 3           3  4  0  0  2  3
# 4           4  0  2  2  4  4
# 5           5  1  0  0  3  4
# 6           6  0  1  3  1  4
# 7           7  0  1  4  3  3
# 8           8  3  1  3  1  1
# 9           9  1  1  2  1  0

# %%
pd.set_option("io.parquet.engine", "fastparquet")

df.columns = df.columns.astype(str)

df.to_parquet("foo.parquet")

# %%
pd.read_parquet("foo.parquet")
# Out:
#    0  1  2  3  4
# 0  3  3  3  1  1
# 1  3  4  0  0  4
# 2  1  2  0  1  2
# 3  4  0  0  2  3
# 4  0  2  2  4  4
# 5  1  0  0  3  4
# 6  0  1  3  1  4
# 7  0  1  4  3  3
# 8  3  1  3  1  1
# 9  1  1  2  1  0

# %%
pd.read_parquet("foo.parquet", engine="fastparquet")
# Out:
#    0  1  2  3  4
# 0  3  3  3  1  1
# 1  3  4  0  0  4
# 2  1  2  0  1  2
# 3  4  0  0  2  3
# 4  0  2  2  4  4
# 5  1  0  0  3  4
# 6  0  1  3  1  4
# 7  0  1  4  3  3
# 8  3  1  3  1  1
# 9  1  1  2  1  0

# %%
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  1  0  0  1  0
# 1           1  1  2  4  0  1
# 2           2  3  2  2  0  2
# 3           3  2  3  1  4  1
# 4           4  4  3  0  4  2
# 5           5  2  0  3  1  3
# 6           6  4  1  0  3  1
# 7           7  4  2  0  4  0
# 8           8  4  4  0  4  1
# 9           9  4  4  3  3  1

# %%
In [141]: if pd.Series([False, True, False]):
   .....:      print("I was true")
   .....:
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[875], line 1
# ----> 1 if pd.Series([False, True, False]):
#       2      print("I was true")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\generic.py:1580, in NDFrame.__nonzero__(self)
#    1578 @final
#    1579 def __nonzero__(self) -> NoReturn:
# -> 1580     raise ValueError(
#    1581         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1582         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1583     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
